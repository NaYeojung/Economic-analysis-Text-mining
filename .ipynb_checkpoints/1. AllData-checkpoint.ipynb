# %%
import pandas as pd

# %%
df = pd.read_csv('mpb_list.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                title        date  \
# 0             0           0  금융통화위원회 의사록(2024년도 제10차)(2024.5.23)  2024.06.11
# 1             1           1    금융통화위원회 의사록(2024년도 제9차)(2024.5.9)  2024.05.28
# 2             2           2   금융통화위원회 의사록(2024년도 제7차)(2024.4.12)  2024.04.30
# 3             3           3   금융통화위원회 의사록(2024년도 제6차)(2024.3.28)  2024.04.16
# 4             4           4   금융통화위원회 의사록(2024년도 제5차)(2024.3.14)  2024.04.02
#
#                                   Economic Situation  \
# 0  ['일부 위원은 OPEC 결속력 약화, 미국의 원유 생산능력 증가 등을 고려하면국제...
# 1                                                 []
# 2  ['일부 위원은 소비자물가 상승률에 대한 식료품의 기여도가 미국이나 유로지역에서는 ...
# 3                                                 []
# 4                                                 []
#
#                                     Foreign Currency Financial Markets  \
# 0  ['일부 위원은 유로지역 등 주요국이 미국에 앞서 선제적으로 정책금리를 인하할 가능...                []
# 1                                                 []                []
# 2  ['일부 위원은 미국 소비자물가(2024.3월) 발표 이후 일각에서 미 연준의 금리...                []
# 3                                                 []                []
# 4                                                 []                []
#
#   Monetary Policy                                Participants’ Views  \
# 0              []  ['일부 위원은 OPEC 결속력 약화, 미국의 원유 생산능력 증가 등을 고려하면국제...
# 1              []                                                 []
# 2              []  ['일부 위원은 소비자물가 상승률에 대한 식료품의 기여도가 미국이나 유로지역에서는 ...
# 3              []                                                 []
# 4              []                                                 []
#
#   Government’s View
# 0                []
# 1                []
# 2                []
# 3                []
# 4                []

# %%
df_2=df[['date','title']]
df_2['content']=df['Economic Situation']+df['Monetary Policy']
df_2
# Out:
# C:\Users\duwjd\AppData\Local\Temp\ipykernel_17336\4270933586.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['content']=df['Economic Situation']+df['Monetary Policy']
#            date                                title  \
# 0    2024.06.11  금융통화위원회 의사록(2024년도 제10차)(2024.5.23)
# 1    2024.05.28    금융통화위원회 의사록(2024년도 제9차)(2024.5.9)
# 2    2024.04.30   금융통화위원회 의사록(2024년도 제7차)(2024.4.12)
# 3    2024.04.16   금융통화위원회 의사록(2024년도 제6차)(2024.3.28)
# 4    2024.04.02   금융통화위원회 의사록(2024년도 제5차)(2024.3.14)
# ..          ...                                  ...
# 215  2013.05.28    금융통화위원회 의사록(2013년도 제9차)(2013.5.9)
# 216  2013.05.14   금융통화위원회 의사록(2013년도 제8차)(2013.4.25)
# 217  2013.04.30   금융통화위원회 의사록(2013년도 제7차)(2013.4.11)
# 218  2013.04.16   금융통화위원회 의사록(2013년도 제6차)(2013.3.28)
# 219  2013.04.02   금융통화위원회 의사록(2013년도 제5차)(2013.3.14)
#
#                                                content
# 0    ['일부 위원은 OPEC 결속력 약화, 미국의 원유 생산능력 증가 등을 고려하면국제...
# 1                                                 [][]
# 2    ['일부 위원은 소비자물가 상승률에 대한 식료품의 기여도가 미국이나 유로지역에서는 ...
# 3                                                 [][]
# 4                                                 [][]
# ..                                                 ...
# 215  ['일부 위원은 GDP성장률이 지난해 2%에 이어올해도 2.6%에 그칠 것으로 예상...
# 216                                               [][]
# 217  ['일부 위원은 현 시점에서 기준금리 인하가 투자와 소비에 어느 정도 실효성이 있을...
# 218                                               [][]
# 219  ['일부 위원은 최근 들어 주요 실물지표들이 등락을 반복하고 있고, 경기둔화에 대한...
#
# [220 rows x 3 columns]

# %%
import re

df_2['date'] = pd.to_datetime(df_2['date'])
df_filtered = df_2[df_2['date'] >= '2014-01-01']
for i in range(len(df_filtered['date'])):

    text=df_filtered.iloc[i,1]
    match = re.search(r'\(([^()]+)\)\s*$', text)

    if match:
        extracted_text = match.group(1)
    df_filtered.iloc[i,0]=extracted_text


df_filtered
# Out:
# C:\Users\duwjd\AppData\Local\Temp\ipykernel_17336\1558573975.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['date'] = pd.to_datetime(df_2['date'])
#           date                                  title  \
# 0   2024-05-23    금융통화위원회 의사록(2024년도 제10차)(2024.5.23)
# 1   2024-05-09      금융통화위원회 의사록(2024년도 제9차)(2024.5.9)
# 2   2024-04-12     금융통화위원회 의사록(2024년도 제7차)(2024.4.12)
# 3   2024-03-28     금융통화위원회 의사록(2024년도 제6차)(2024.3.28)
# 4   2024-03-14     금융통화위원회 의사록(2024년도 제5차)(2024.3.14)
# ..         ...                                    ...
# 199 2014-03-27    금융통화위원회 의사록(2014년도 제6차)(2014.3.27.)
# 200 2014-03-13    금융통화위원회 의사록(2014년도 제5차)(2014.3.13.)
# 201 2014-02-13    금융통화위원회 의사록(2014년도 제3차)(2014.2.13.)
# 202 2014-01-09      금융통화위원회 의사록(2014년도 제1차)(2014.1.9)
# 203 2013-12-26  금융통화위원회 의사록(2013년도 제24차)(2013.12.26.)
#
#                                                content
# 0    ['일부 위원은 OPEC 결속력 약화, 미국의 원유 생산능력 증가 등을 고려하면국제...
# 1                                                 [][]
# 2    ['일부 위원은 소비자물가 상승률에 대한 식료품의 기여도가 미국이나 유로지역에서는 ...
# 3                                                 [][]
# 4                                                 [][]
# ..                                                 ...
# 199                                               [][]
# 200  ['일부 위원은 ‘경제혁신 3개년 계획’ 등 정부의경제활성화 방안들이 주택가격 급등...
# 201                                               [][]
# 202                                               [][]
# 203                                               [][]
#
# [204 rows x 3 columns]

# %%
df_filtered=df_filtered[df_filtered['content']!='[][]']
df_filtered.to_csv('minutes_test.csv',encoding='utf-8-sig')

# %%
df2=pd.read_csv('financial_report.csv')
df2=df2.drop('company',axis=1)
df2=df2.drop('view',axis=1)
df2['date']= pd.to_datetime(df2['date'])
df2 = df2['2014-01-01'<=df2['date']]
df2=df2['2024-06-30'>=df2['date']]
df2 = df2.sort_values(by='date')
df2.reset_index(drop=True, inplace=True)
df2
# Out:
# C:\Users\duwjd\AppData\Local\Temp\ipykernel_6472\3247206010.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df2['date']= pd.to_datetime(df2['date'])
#            date                            title  \
# 0    2014-01-13  1월 금통위 – 아직 끝나지 않은 ‘금리인하 Cycle’
# 1    2014-01-13      금리 인하 기대 다시 커지며 채권금리 재하락 예상
# 2    2014-01-13                  금리는 다시 박스권 상단으로
# 3    2014-01-13                     크레딧 채권 강세 전환
# 4    2014-01-14           회사채 시장 정상화를 위한 넛지-투자자편
# ...         ...                              ...
# 1225 2024-06-13      포트폴리오 리밸런싱을 염두에 둔 보수적 대응 유지
# 1226 2024-06-13              정부의 시장 안정 조치에 대한 기대
# 1227 2024-06-13                     패닉보다는 관망세 유지
# 1228 2024-06-15            피치 한국 가계부채 취약에도 등급 유지
# 1229 2024-06-19           글로벌 인하싸이클 진입에 환호하는 선진국
#
#                                                 content
# 0     Microsoft Word - BondMonetaryPolicy_130114_ocs...
# 1     Microsoft Word - 130114-WeeklyBondMarket(교정)  ...
# 2     Microsoft Word - HMC_FI_weekly_13.01.14.doc   ...
# 3     <그림1> 주요금리와 크레딧 스프레드(회사채 AA- 3년물, 국고채대비) 2.02....
# 4     Microsoft Word - TC_140114.doc  www.ibks.com 본...
# ...                                                 ...
# 1225  FI Strategist 정성욱 02) 2184-2368 swjung@ktb.co....
# 1226  Microsoft Word - HMC_FI_weekly_13.06.24.doc   ...
# 1227  <그림1> 국고채 10년물과 회사채AA-3년물 금리 추이 2.62.72.82.93....
# 1228  <BABBB5E520C5A9B7B9B5F720B5A5C0CFB8AE20C6F7B8C...
# 1229  2013년 0월 0일          글로벌 읶하싸이클 진입에 환호하는 선진국Inv...
#
# [1230 rows x 3 columns]

# %%
import re

def clean_text(text):
    pattern = (
        r"^\s*뉴스\s*[0-9]{4}년\s*[0-9]{1,2}월\s*[0-9]{1,2}일\s*.*?\n"
        r"|.*기자.*\n©\s*[0-9]{4}\s*(뉴스사|서울경제)\s*.*$"
    )
    text = re.sub(pattern, '', text, flags=re.MULTILINE | re.DOTALL)

    return text.strip()

# %%
df3=pd.read_csv('news_list.csv')
df3 = df3.sort_values(by='date')
df3['date']= pd.to_datetime(df3['date'])
df3.reset_index(drop=True, inplace=True)

for i in range(len(df3['content'])):
    text=df3.iloc[i,2]
    cleaned_text=clean_text(text)
    df3.iloc[i,2]=cleaned_text

df3
# Out:
#            date                                          title  \
# 0    2024-01-01  이수근도 "코인 투자, 마이너스 92%" 고백…암호화폐 전망은 [이슈, 풀어주리]
# 1    2024-01-01              기시다 "올해 디플레 탈출"…도쿄일렉, 신입초임 40% 껑충
# 2    2024-01-01         이창용 “경제 어려울 때마다 부채 늘리는 임기응변식 성장 시대 끝나”
# 3    2024-01-01      “발걸음 참 무겁네요” 새해 밝았지만…자동차·철강·IT 회사들 ‘불안불안’
# 4    2024-01-01      한국, G5 진입땐 국가가치 101조 ‘수직 상승’…수출 늘고 신인도 상승
# ...         ...                                            ...
# 4468 2024-03-31                       너무 뜨거운 고용시장…금리인하 불씨 꺼트리나
# 4469 2024-03-31                       너무 뜨거운 고용시장…금리인하 불씨 꺼트리나
# 4470 2024-03-31            美에 쏠린 눈…고용·실업지수, 파월 연설 '주목'[글로벌증시뷰]
# 4471 2024-03-31               내일부터 중견·중소 대상 11조원 은행권 지원프로그램 개시
# 4472 2024-03-31                       너무 뜨거운 고용시장…금리인하 불씨 꺼트리나
#
#                                                 content
# 0     [서울경제] 출근길에서도, 퇴근길에서도. 온·오프라인에서 화제가 되고 있는 다양한 ...
# 1     물가 웃도는 임금 상승 언급에기업들 높은 인상안 잇단 발표유통기업 이온 파트시급 7...
# 2     가계부채 등 구조 문제 해결책 주문올해 국내 여건에 무게 두고 정책부동산 PF 부실...
# 3     기업 82%는 현상유지·긴축경영새해 초 경영 전망도 ‘부정적’美 통화긴축·中 경제 ...
# 4     韓기업 수출 늘고, 정부 국채비용 감소◆ 5·5·5 담대한 도전 ◆\n\n\n\n ...
# ...                                                 ...
# 4468  ◆ 제22대 국회의원선거 ◆\n\n\n\n 서울 여의도 산업은행. [메경DB]4·1...
# 4469  역세권(驛勢圈)은 성인 걸음으로 대개 10분 이내 거리로 약 500m 가량입니다. ...
# 4470  3월 고용보고서 나와...비농업고용 증가할 듯실업률도 전월 3.9% 수준 유지할 것...
# 4471  저리 대출프로그램 6조·이자경감 5조[이데일리 송주오 기자] 내일(4월 1일)부터 ...
# 4472  금리인하 기대에 리츠 부상수도권 오피스 담아야 수익률 쑥\n\n\n\n 신한 L타워...
#
# [4473 rows x 3 columns]

# %%
all_df=pd.concat([df_filtered,df2,df3])
all_df = all_df.sort_values(by='date')
all_df.reset_index(drop=True, inplace=True)
all_df
# Out:
#            date                                  title  \
# 0    2013-12-26  금융통화위원회 의사록(2013년도 제24차)(2013.12.26.)
# 1    2014-01-09      금융통화위원회 의사록(2014년도 제1차)(2014.1.9)
# 2    2014-01-13        1월 금통위 – 아직 끝나지 않은 ‘금리인하 Cycle’
# 3    2014-01-13                           크레딧 채권 강세 전환
# 4    2014-01-13                        금리는 다시 박스권 상단으로
# ...         ...                                    ...
# 5902 2024-06-13                    정부의 시장 안정 조치에 대한 기대
# 5903 2024-06-13                           패닉보다는 관망세 유지
# 5904 2024-06-13            포트폴리오 리밸런싱을 염두에 둔 보수적 대응 유지
# 5905 2024-06-15                  피치 한국 가계부채 취약에도 등급 유지
# 5906 2024-06-19                 글로벌 인하싸이클 진입에 환호하는 선진국
#
#                                                 content
# 0                                                  [][]
# 1                                                  [][]
# 2     Microsoft Word - BondMonetaryPolicy_130114_ocs...
# 3     <그림1> 주요금리와 크레딧 스프레드(회사채 AA- 3년물, 국고채대비) 2.02....
# 4     Microsoft Word - HMC_FI_weekly_13.01.14.doc   ...
# ...                                                 ...
# 5902  Microsoft Word - HMC_FI_weekly_13.06.24.doc   ...
# 5903  <그림1> 국고채 10년물과 회사채AA-3년물 금리 추이 2.62.72.82.93....
# 5904  FI Strategist 정성욱 02) 2184-2368 swjung@ktb.co....
# 5905  <BABBB5E520C5A9B7B9B5F720B5A5C0CFB8AE20C6F7B8C...
# 5906  2013년 0월 0일          글로벌 읶하싸이클 진입에 환호하는 선진국Inv...
#
# [5907 rows x 3 columns]

# %%
all_df.to_csv('all_data_df.csv', encoding='utf-8-sig')
